# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Exercício 1 A

# %%
# conjunto de dados
dados = [['Investir mais em ações',562],["Não investir",288],
["Investir mais em títulos",144],["Investir o mesmo valor de 2012",461]]
tabela = pd.DataFrame(dados,columns=['Título','Frequência'])
display(tabela)

# construção do gráfico
pizza = plt.pie(tabela['Frequência'], labels=tabela['Título'],
                autopct='%1.1f%%', wedgeprops = {"edgecolor" : "black"},
                shadow=True)
# Out:
#                            Título  Frequência
# 0          Investir mais em ações         562
# 1                    Não investir         288
# 2        Investir mais em títulos         144
# 3  Investir o mesmo valor de 2012         461

# %% [markdown]
# Exercício 1 B

# %%
# conjunto de dados
dados = [["Estados Unidos",15],["Tanzânia",1],["Grã-Bretanha",1],["Itália",4],
["Quênia",9],["Brasil",2],["Etiópia",2],["México",4],["Nova Zelândia",1],
["África do Sul",2],["Marrocos",1]]
tabela = pd.DataFrame(dados,columns=['Título','Frequência'])
display(tabela)

# construção do gráfico
pizza = plt.pie(tabela['Frequência'], labels=tabela['Título'],
                autopct='%1.1f%%', wedgeprops = {"edgecolor" : "black"},
                shadow=True)
# Out:
#             Título  Frequência
# 0   Estados Unidos          15
# 1         Tanzânia           1
# 2     Grã-Bretanha           1
# 3           Itália           4
# 4           Quênia           9
# 5           Brasil           2
# 6          Etiópia           2
# 7           México           4
# 8    Nova Zelândia           1
# 9    África do Sul           2
# 10        Marrocos           1

# %% [markdown]
# Exercício 2

# %%
# conjunto de dados
dados = [["América",21],["África",15],["Europa",5],["Oceania",1]]
tabela = pd.DataFrame(dados,columns=['Título','Frequência'])
display(tabela)

# construção do gráfico
pizza = plt.pie(tabela['Frequência'], labels=tabela['Título'],
                autopct='%1.1f%%', wedgeprops = {"edgecolor" : "black"},
                shadow=True)
# Out:
#     Título  Frequência
# 0  América          21
# 1   África          15
# 2   Europa           5
# 3  Oceania           1

# %% [markdown]
# Exercício 3 A

# %%
#conjunto de dados
dados = pd.DataFrame({'Valores': [44,65,104,82,88]})
dados.index = ["Alemanha","Grã-Bretanha","Estados\nUnidos","Rússia","China"]
# organizando dados
dados = dados.sort_values(by='Valores', ascending=False)
# frequencia acumulada
dados['PorcAcum'] = dados['Valores'].cumsum()/dados['Valores'].sum()*100

# criando o grafico
from matplotlib.ticker import PercentFormatter
# Definição das cores
cor_barra = 'steelblue'
cor_linha = 'green'
tam_linha = 4
# construção dos graficos
fig, pareto = plt.subplots()
#grafico de barras
pareto.bar(dados.index, dados['Valores'], color=cor_barra)
pareto.set(xlabel='Causas',
           ylabel='Bilhões de dólares',
           title = 'Principais causas de redução de estoque')
# criando texto das barras
barras = pareto.patches
valores = dados['Valores']
for barra, valor in zip(barras, valores):
    altura = barra.get_height()
    pareto.text(barra.get_x()+barra.get_width()/2, altura,
                valor, ha='center', va='bottom')

# %% [markdown]
# Exercício 3 B

# %%
#conjunto de dados
dados = pd.DataFrame({'Valores': [27,54,2,37,57,2]})
dados.index = ["Drogas não\n autorizadas","Omissão","Froma\nincorreta\nda droga","Período\nincorreto","Dose\nindequada","Droga\ndeteriorada"]
# organizando dados
dados = dados.sort_values(by='Valores', ascending=False)
# frequencia acumulada
dados['PorcAcum'] = dados['Valores'].cumsum()/dados['Valores'].sum()*100

# criando o grafico
from matplotlib.ticker import PercentFormatter
# Definição das cores
cor_barra = 'steelblue'
cor_linha = 'green'
tam_linha = 4
# construção dos graficos
fig, pareto = plt.subplots()
#grafico de barras
pareto.bar(dados.index, dados['Valores'], color=cor_barra)
pareto.set(xlabel='Causas',
           ylabel='Bilhões de dólares',
           title = 'Principais causas de redução de estoque')
# criando texto das barras
barras = pareto.patches
valores = dados['Valores']
for barra, valor in zip(barras, valores):
    altura = barra.get_height()
    pareto.text(barra.get_x()+barra.get_width()/2, altura,
                valor, ha='center', va='bottom')

# %% [markdown]
# Exercício 4

# %%
data = {"Número de aluno pr professor":[17.1,17.5,18.9,17.1,20,18.6,14.4,16.5,13.3,18.4],
"Salário médio dos professores":[28.7,47.5,31.8,28.1,40.3,33.8,49.8,37.5,42.5,31.9]}
df = pd.DataFrame(data = data)
df.plot.scatter(x = 'Número de aluno pr professor', y = 'Salário médio dos professores', s = 'Salário médio dos professores', c = 'red')
# Out:
# <AxesSubplot:xlabel='Número de aluno pr professor', ylabel='Salário médio dos professores'>

# %% [markdown]
# Exércicio 5

# %%
data = {"Ano":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011],
"Registros":[4.3,4.9,5,5.4,5.8,6.2,6.7,7.1,7.8,7.9,8.2,8.3]}
df = pd.DataFrame(data = data)
df.plot.scatter(x = 'Ano', y = 'Registros', s = 'Registros', c = 'red')
# Out:
# <AxesSubplot:xlabel='Ano', ylabel='Registros'>
